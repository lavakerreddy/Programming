# %%
def Player_InputValues():
       
        PostiTimes = 9;
        list_Tic_Tac_Toe =['#',' ',' ',' ',' ',' ',' ',' ',' ',' '];
        
        print("WELCOME TO TIC TAC TOE !!!\n\n FIRST PLAYER 'X', SECOND PLAYER 'O'\n\n");
        
        
        while PostiTimes >= 1 :
            
            
            if PostiTimes%2 != 0 :
                PostiVal=int(input("FIRST PLAYER PLEASE ENTER POSITION (1-9) :: "),10);
            else:
                PostiVal=int(input("SECOND PLAYER PLEASE ENTER POSITION (1-9) :: "),10);
            
            if (1 <= PostiVal <= 9 ): 
                if(list_Tic_Tac_Toe[PostiVal]==' '):
                    if PostiTimes%2==1:
                        list_Tic_Tac_Toe[PostiVal]='X';
                    else:
                        list_Tic_Tac_Toe[PostiVal]='O';
                       
                    PostiTimes = PostiTimes - 1 ;
                    
                else:
                    print("POSITION WAS ALREADY FILLED\n\n")

                print(list_Tic_Tac_Toe[1],"|",list_Tic_Tac_Toe[2],"|",list_Tic_Tac_Toe[3])
                print("- | - | -")
                print(list_Tic_Tac_Toe[4],"|",list_Tic_Tac_Toe[5],"|",list_Tic_Tac_Toe[6])
                print("- | - | -")
                print(list_Tic_Tac_Toe[7],"|",list_Tic_Tac_Toe[8],"|",list_Tic_Tac_Toe[9])
                print("\n\n")
            else:
                print("INVALID INPUT\n\n")
            
            
            
            if((list_Tic_Tac_Toe[1] == 'X' and list_Tic_Tac_Toe[2] == 'X' and list_Tic_Tac_Toe[3] == 'X') or
               (list_Tic_Tac_Toe[4] == 'X' and list_Tic_Tac_Toe[5] == 'X' and list_Tic_Tac_Toe[6] == 'X') or
               (list_Tic_Tac_Toe[7] == 'X' and list_Tic_Tac_Toe[8] == 'X' and list_Tic_Tac_Toe[9] == 'X') or
               (list_Tic_Tac_Toe[1] == 'X' and list_Tic_Tac_Toe[4] == 'X' and list_Tic_Tac_Toe[7] == 'X') or
               (list_Tic_Tac_Toe[2] == 'X' and list_Tic_Tac_Toe[5] == 'X' and list_Tic_Tac_Toe[8] == 'X') or
               (list_Tic_Tac_Toe[3] == 'X' and list_Tic_Tac_Toe[6] == 'X' and list_Tic_Tac_Toe[9] == 'X') or
               (list_Tic_Tac_Toe[1] == 'X' and list_Tic_Tac_Toe[5] == 'X' and list_Tic_Tac_Toe[9] == 'X') or
               (list_Tic_Tac_Toe[7] == 'X' and list_Tic_Tac_Toe[5] == 'X' and list_Tic_Tac_Toe[3] == 'X')):
                print("FIRST PLAYER WON THE GAME\n")
                PostiTimes=0;
            elif((list_Tic_Tac_Toe[1] == 'O' and list_Tic_Tac_Toe[2] == 'O' and list_Tic_Tac_Toe[3] == 'O') or
               (list_Tic_Tac_Toe[4] == 'O' and list_Tic_Tac_Toe[5] == 'O' and list_Tic_Tac_Toe[6] == 'O') or
               (list_Tic_Tac_Toe[7] == 'O' and list_Tic_Tac_Toe[8] == 'O' and list_Tic_Tac_Toe[9] == 'O') or
               (list_Tic_Tac_Toe[1] == 'O' and list_Tic_Tac_Toe[4] == 'O' and list_Tic_Tac_Toe[7] == 'O') or
               (list_Tic_Tac_Toe[2] == 'O' and list_Tic_Tac_Toe[5] == 'O' and list_Tic_Tac_Toe[8] == 'O') or
               (list_Tic_Tac_Toe[3] == 'O' and list_Tic_Tac_Toe[6] == 'O' and list_Tic_Tac_Toe[9] == 'O') or
               (list_Tic_Tac_Toe[1] == 'O' and list_Tic_Tac_Toe[5] == 'O' and list_Tic_Tac_Toe[9] == 'O') or
               (list_Tic_Tac_Toe[7] == 'O' and list_Tic_Tac_Toe[5] == 'O' and list_Tic_Tac_Toe[3] == 'O')):
                print("SECOND PLAYER WON THE GAME !!!! \n")
                PostiTimes=0;
                
            
        print("GAME OVER !!! ")

# %%
Player_InputValues()
# Out:
# WELCOME TO TIC TAC TOE !!!
#
#  FIRST PLAYER 'X', SECOND PLAYER 'O'
#
#
# FIRST PLAYER PLEASE ENTER POSITION (1-9) :: 9
#   |   |
# - | - | -
#   |   |
# - | - | -
#   |   | X
#
#
#
# SECOND PLAYER PLEASE ENTER POSITION (1-9) :: 5
#   |   |
# - | - | -
#   | O |
# - | - | -
#   |   | X
#
#
#
# FIRST PLAYER PLEASE ENTER POSITION (1-9) :: 5
# POSITION WAS ALREADY FILLED
#
#
#   |   |
# - | - | -
#   | O |
# - | - | -
#   |   | X
#
#
#
# FIRST PLAYER PLEASE ENTER POSITION (1-9) :: 8
#   |   |
# - | - | -
#   | O |
# - | - | -
#   | X | X
#
#
#
# SECOND PLAYER PLEASE ENTER POSITION (1-9) :: 7
#   |   |
# - | - | -
#   | O |
# - | - | -
# O | X | X
#
#
#
# FIRST PLAYER PLEASE ENTER POSITION (1-9) :: 3
#   |   | X
# - | - | -
#   | O |
# - | - | -
# O | X | X
#
#
#
# SECOND PLAYER PLEASE ENTER POSITION (1-9) :: 6
#   |   | X
# - | - | -
#   | O | O
# - | - | -
# O | X | X
#
#
#
# FIRST PLAYER PLEASE ENTER POSITION (1-9) :: 4
#   |   | X
# - | - | -
# X | O | O
# - | - | -
# O | X | X
#
#
# ...
